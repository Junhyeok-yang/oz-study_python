# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# 두 수를 받은 뒤 곱한 결과를 반환하는 oz 함수를 만들어주세요

# %% [markdown]
# <span style="color:red">답변</span>

# %%
def oz(a, b):
    c = a * b
    return c

print("function(123 * 456)=", oz(123, 456))
# Out:
# function(123 * 456)= 56088

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```
# 아래 작성된 코드의 실행 결과를 설명해주세요
#
# print("A")
#
# def message() :
#     print("B")
#
# print("C")
#
# message()
#
# ```

# %% [markdown]
# <span style="color:red">답변</span>

# %%
# 코드는 탑 다운 방식으로 순차적으로 실행
print("A") # 1번으로 실행 a출력

def message() : # 함수 정의. 호출되지 않았기에 실행은 되지 않고 함수만 정의함.
    print("B") 

print("C") #2번으로 실행 c출력

message() #정의한 함수를 호출, 실행 b출력
# Out:
# A
# C
# B

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```매개변수가 없는 oz 함수를 호출하는 방법으로 올바른 것을 골라주세요```
#
# 1. def oz
# 2. oz
# 3. oz( )
# 4. oz[ ]
# 5. def oz:

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3번, 매개변수가 없으면 인자도 비워야함

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문4]<br><br></span>
# ```문자열 하나를 입력받아 인터넷 주소를 반환하는 make_url 함수를 만들어주세요```
#
# 예 ) make_url("google")
#
# 출력 : www.google.com

# %% [markdown]
# <span style="color:red">답변</span>

# %%
def make_url(name):
    return f'"www.{name}.com"'
    
print(make_url("google"))
# Out:
# "www.google.com"

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```아래 코드를 실행했을때 c의 값으로 올바른 것을 골라주세요```
#
# def 함수0(num) :<br>
# &emsp;&emsp;return num * 2<br>
#
# def 함수1(num) :<br>
# &emsp;&emsp;return 함수0(num + 2)<br>
#
# def 함수2(num) :<br>
# &emsp;&emsp;num = num + 10<br>
# &emsp;&emsp;return 함수1(num)<br>
#
# c = 함수2(2)<br>
# print(c)
#
#
# 1. 1
# 2. 5
# 3. 3
# 4. 4
# 5. 28

# %% [markdown]
# <span style="color:red">답변</span>

# %%
def 함수0(num): #6.함수1에서 받은 계산값
    return num * 2 #7.최종계산값을 반환

def 함수1(num): #4.함수2에서 받은 계산값
    return 함수0(num + 2) #5.함수0으로 반환

def 함수2(num): #2. num2를 받아 계산 진행
    num = num + 10
    return 함수1(num) #3. 계산값을 함수1로 반환

c = 함수2(2) #1. 함수2를 호출하여 num 2를 전달
print(c) #8. 출력
# Out:
# 28

# %% [markdown]
# ----
