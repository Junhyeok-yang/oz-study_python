# %%
#주석은 이렇게 하는거다
print("진짜 안보이는 거야?")
# print("신기하네?") '컨트롤 + /' 누르면 주석처리 됨됨
# Out:
# 진짜 안보이는 거야?

# %%
#""""""

# print("진짜 안보이는 거야?")
# print("신기하네?")

# %%
for 동물 in ("토끼" , "사자" , "푸바오" , "호랑이"):
    print(동물)
    print(" 보러 갈래요?")
# Out:
# 토끼
#  보러 갈래요?
# 사자
#  보러 갈래요?
# 푸바오
#  보러 갈래요?
# 호랑이
#  보러 갈래요?
