# %% [markdown]
# ## 1. return
#
# return 키워드 : 함수를 실행한 위치로 되돌아 감, 일반적으로 함수가 끝나는 위치에 return을 사용합니다.

# %%
# 값 없이 리턴하는 경우
def oz_return():
    """
    oz_return 함수는 "파이썬"과 "재미있엉"을 출력하고,
    이후에 함수가 종료됩니다.
    """
    print("파이썬")  # "파이썬"을 출력
    print("재미있엉")  # "재미있엉"을 출력
    return  # 함수 종료, 이후의 코드는 실행되지 않음
    print("거짓말하네")  # 이 코드는 실행되지 않음, return 이후의 코드는 무시됨

# 출력
파이썬
재미있엉

# %% [markdown]
# ![스크린샷 2024-07-09 10.10.54.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. 값과 함께 return

# %%
# 값과 함께 리턴하는 경우
def oz_return():
    """
    oz_return 함수는 "파이썬 재미있엉" 문자열을 반환합니다.

    반환 값:
    - str: "파이썬 재미있엉" 문자열
    """
    return "파이썬 재미있엉"  # "파이썬 재미있엉" 문자열을 반환

# oz_return 함수를 호출하고 그 반환 값을 result 변수에 저장
result = oz_return()

# result 변수의 값을 출력
print(result)  # 출력 결과: "파이썬 재미있엉"

# 출력
파이썬 재미있엉

# %% [markdown]
# ## 3. 아무것도 리턴하지 않는 경우

# %%
def oz_return():
    """
    oz_return 함수는 아무 값도 반환하지 않습니다.
    (즉, None을 반환합니다)
    """
    return  # 아무 값도 반환하지 않음 (None 반환)

# oz_return 함수를 호출하고 그 반환 값을 result 변수에 저장
result = oz_return()

# result 변수의 값을 출력
print(result)  # 출력 결과: None

# 출력
None

# %% [markdown]
# ## 4. input  함수

# %%
result = input("1 + 1은 ?")
print(result)

#출력
2

# %% [markdown]
# input() 함수는 값을 입력받을 수 있게 해주는 기능을 가지고 있는 것으로만 생각하고 사용해왔습니다. return이라는 개념을 넣어서 이 과정을 설명해볼 수 있을 것 같습니다.
#
# input()함수는 입력받은 값을 문자열로 돌려줍니다. 여기서 **돌려준다**는 의미는 **return** 한다는 의미와 같습니다.
#
# 그렇기 때문에 input()을 통해 입력받은 값을 변수에 담아 사용할 수 있게 되는겁니다.
#
# 대부분 무엇인가를 반환하는 함수들은 return을 이용한다고 생각하시면 됩니다.

# %% [markdown]
# ## 이해도 체크리스트
#
# <aside>
# ⚠️ 해당 체크리스트는 본 챕터의 이해도를 확인하는 문제입니다. 대답에 어려움을 느끼신다면, 다시 한번 강의를 수강하는 것을 추천드립니다.
#
# </aside>
#
# 1. 다음 코드의 출력 결과는 무엇인가요?
#
#     ```python
#     def example():
#     	print("Hello")
#     	return
#     	print("World")
#
#     example()
#     ```
#
#     a) Hello
#
#     b) Hello World
#
#     c) World
#
#     d) Systax Error
#
#     - 정답
#
#         a
#
#         return 이후의 코드는 실행되지 않기 때문에 “Hello”만 출력됩니다.
#
#
# 1. 다음 코드의 출력 결과는 무엇인가요?
#
#     ```python
#     def add(a, b):
#     	return a + b
#
#     result = add(3, 5)
#     print(result)
#     ```
#
#     a) 8
#
#     b) 35
#
#     c) None
#
#     d) Syntax Error
#
#     - 정답
#
#         a
#
#         add 함수는 두 인자의 합을 반환하므로, result 변수는 8을 저장하게 되고, 출력 결과는 8입니다.
#
#
# 1. 다음 코드의 출력 결과는 무엇인가요?
#
#     ```python
#     def nothing():
#     	return
#
#     result = nothing()
#     print(result)
#     ```
#
#     a) 0
#
#     b) None
#
#     c) Syntax Error
#
#     d) Nothing
#
#     - 정답
#
#         b
#         함수 do_nothing은 아무 값도 반환하지 않으므로, None이 반환되고 출력 결과도 None이 됩니다.
