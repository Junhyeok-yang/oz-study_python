# %% [markdown]
# ## 1. try except 구문이란?
#
# 모든 예외처리 사항을 조건문으로 처리하는건 굉장히 귀찮고 어려운 문제입니다.
#
# 요즘 프로그램은 대부분 예외를 처리하는 구문을 제공합니다.

# %% [markdown]
# ## 2. try except의 구조

# %%
#구조
try:
	예외가 발생할 가능성이 있는 코드
except:
	예외가 발생했을 때 실행할 코드

# %%
#try except의 사

try:
    # 사용자로부터 밑변과 높이를 입력받습니다.
    # 입력받은 값들을 공백을 기준으로 나누고, 각각 정수로 변환합니다.
    x, y = map(int, input("밑변과 높이를 입력해주세요").split(" "))

    # 삼각형의 넓이를 계산하여 출력합니다.
    # 넓이는 밑변 * 높이 / 2 로 계산됩니다.
    print(f'삼각형의 넓이는 {x * y / 2}입니다.')
except:
    # 예외가 발생하면 (입력값이 정수가 아니거나 다른 오류가 발생한 경우)
    # 오류 메시지를 출력합니다.
    print("정수로 입력하지 않아 계산이 불가능합니다.")

# 입력
3 5

# 출력
삼각형의 넓이는 7.5입니다.

# 입력
3cm 5cm

# 출력
정수로 입력하지 않아 계산이 불가능합니다.

# %% [markdown]
# ## 3. try except 구문과 pass 키워드
#
# 예외가 발생하더라도 지금 **당장 처리하지 않아도 되는 부분**이라면 pass 키워드를 사용하여 넘어갑니다.

# %%
#구조
try:
	예외가 발생할 가능성이 있는 코드
except:
	pass

# %%
# try except구문에서의 pass 사용

# 문자열로 이루어진 리스트를 정의합니다. 스파이는 숫자로 변환이 불가능합니다.
list_input = ["1", "7", "3", "스파이", "4"]

# 정수로 변환 가능한 항목들을 저장할 빈 리스트를 정의합니다.
list_number = []

# 입력 리스트의 각 항목을 순회합니다.
for item in list_input:
    try:
        # 항목을 정수로 변환 시도합니다.
        int(item)
        # 변환이 성공하면 리스트에 추가합니다.
        list_number.append(item)
    except:
        # 변환에 실패하면 (예외가 발생하면) 아무 작업도 하지 않고 넘어갑니다.
        pass

# 입력 리스트에 있는 숫자들을 출력합니다.
print(f'{list_input} 내부에 있는 숫자는')
print(f'{list_number}입니다.')

#출력
['1', '7', '3', '스파이', '4'] 내부에 있는 숫자는
['1', '7', '3', '4']입니다.

# %% [markdown]
# ## 4. try except 구문과 else 키워드
#
# else 구문을 붙여서 사용하면 **예외가 발생하지 않았을 때 실행할 코드**를 지정할 수 있습니다.

# %%
#구조
try:
	예외가 발생할 가능성이 있는 코드
except:
	예외가 발생했을 때 실행할 코드
else:
	예외가 발생하지 않았을 때 실행할 코드

# %%
# try excpet 구문에서의 else 사용

try:
    # 사용자로부터 밑변과 높이를 입력받습니다.
    # 입력받은 값들을 공백을 기준으로 나누고, 각각 정수로 변환합니다.
    x, y = map(int, input("밑변과 높이를 입력해주세요").split(" "))
except:
    # 예외가 발생하면 (입력값이 정수가 아니거나 다른 오류가 발생한 경우)
    # 오류 메시지를 출력합니다.
    print("정수로 입력하지 않아 계산이 불가합니다.")
else:
    # 예외가 발생하지 않은 경우, 삼각형의 넓이를 계산하여 출력합니다.
    # 넓이는 밑변 * 높이 / 2 로 계산됩니다.
    print(f'삼각형의 넓이는 {x * y / 2}입니다.')

# %% [markdown]
# ## 5. try except 구문과 finally 키워드
#
# finally는 예외 처리 구문에서 가장 **마지막**에 사용할 수 있는 구문입니다.
#
# 예외 발생 여부와 관계 없이 무조건 실행되는 코드입니다.

# %%
#구조
try:
	예외가 발생할 가능성이 있는 코드
except:
	예외가 발생했을 때 실행할 코드
else:
	예외가 발생하지 않았을 때 실행할 코드
finally:
	무조건 실행할 코드

# %%
# try except 구문에서의 finally 사용

try:
    # 사용자로부터 밑변과 높이를 입력받습니다.
    # 입력받은 값들을 공백을 기준으로 나누고, 각각 정수로 변환합니다.
    x, y = map(int, input("밑변과 높이를 입력해주세요").split(" "))
except:
    # 예외가 발생하면 (입력값이 정수가 아니거나 다른 오류가 발생한 경우)
    # 오류 메시지를 출력합니다.
    print("정수로 입력하지 않아 계산이 불가합니다.")
else:
    # 예외가 발생하지 않은 경우, 삼각형의 넓이를 계산하여 출력합니다.
    # 넓이는 밑변 * 높이 / 2 로 계산됩니다.
    print(f'삼각형의 넓이는 {x * y / 2}입니다.')
finally:
    # 예외 발생 여부와 관계없이 항상 실행되는 코드 블록입니다.
    # 프로그램이 종료되었음을 알리는 메시지를 출력합니다.
    print("프로그램이 종료 되었습니다.")

# %% [markdown]
# return 구문으로 함수를 빠져나오더라도 finally 구문이 있다면 finally 구문이 실행됩니다.
#
# 또한, 반복문의 break문을 만나 빠져나와도 finally 구문이 있다면 finally 구문이 실행됩니다.

# %% [markdown]
# ## 6. try except finally 구문의 정리
#
# ### try ~ except
#
# 이 구문은 오류가 발생할 수 있는 코드 블록을 실행하고, 오류가 발생했을 때 이를 처리하는 블록을 정의합니다.

# %%
python코드 복사
try:
    # 오류가 발생할 수 있는 코드
except:
    # 오류가 발생했을 때 실행할 코드

# %% [markdown]
# **설명:**
#
# - `try` 블록 내의 코드가 실행됩니다.
# - 만약 오류가 발생하면, `except` 블록이 실행됩니다.
# - 오류가 발생하지 않으면 `except` 블록은 실행되지 않습니다.

# %% [markdown]
# ### try ~ except ~ else
#
# 이 구문은 오류가 발생하지 않을 때 실행할 코드를 추가로 정의할 수 있습니다.

# %%
python코드 복사
try:
    # 오류가 발생할 수 있는 코드
except:
    # 오류가 발생했을 때 실행할 코드
else:
    # 오류가 발생하지 않았을 때 실행할 코드

# %% [markdown]
# **설명:**
#
# - `try` 블록 내의 코드가 실행됩니다.
# - 오류가 발생하면 `except` 블록이 실행됩니다.
# - 오류가 발생하지 않으면 `else` 블록이 실행됩니다.

# %% [markdown]
# ### try ~ except ~ finally
#
# 이 구문은 오류 발생 여부와 관계없이 항상 실행할 코드를 정의할 수 있습니다.

# %%
python코드 복사
try:
    # 오류가 발생할 수 있는 코드
except:
    # 오류가 발생했을 때 실행할 코드
finally:
    # 오류 발생 여부와 관계없이 항상 실행할 코드

# %% [markdown]
# **설명:**
#
# - `try` 블록 내의 코드가 실행됩니다.
# - 오류가 발생하면 `except` 블록이 실행됩니다.
# - `finally` 블록은 오류 발생 여부와 관계없이 항상 실행됩니다.

# %% [markdown]
# ### try ~ except ~ else ~ finally
#
# 이 구문은 모든 경우의 예외 처리를 포함하며, 오류가 발생하지 않았을 때와 항상 실행할 코드를 모두 정의할 수 있습니다.

# %%
python코드 복사
try:
    # 오류가 발생할 수 있는 코드
except:
    # 오류가 발생했을 때 실행할 코드
else:
    # 오류가 발생하지 않았을 때 실행할 코드
finally:
    # 오류 발생 여부와 관계없이 항상 실행할 코드

# %% [markdown]
# **설명:**
#
# - `try` 블록 내의 코드가 실행됩니다.
# - 오류가 발생하면 `except` 블록이 실행됩니다.
# - 오류가 발생하지 않으면 `else` 블록이 실행됩니다.
# - `finally` 블록은 오류 발생 여부와 관계없이 항상 실행됩니다.

# %% [markdown]
# ### try ~ finally
#
# 이 구문은 오류 처리 코드를 생략하고, 항상 실행할 코드만 정의할 수 있습니다.

# %%
python코드 복사
try:
    # 오류가 발생할 수 있는 코드
finally:
    # 오류 발생 여부와 관계없이 항상 실행할 코드

# %% [markdown]
# **설명:**
#
# - `try` 블록 내의 코드가 실행됩니다.
# - `finally` 블록은 오류 발생 여부와 관계없이 항상 실행됩니다.

# %% [markdown]
# ## 이해도 체크리스트
#
# <aside>
# ⚠️ 해당 체크리스트는 본 챕터의 이해도를 확인하는 문제입니다. 대답에 어려움을 느끼신다면, 다시 한번 강의를 수강하는 것을 추천드립니다.
#
# </aside>
#
# 1. try ~ except 구문의 사용 이유와 방법을 설명해주세요
#     - 정답
#
#         ### 사용 이유
#
#         `try ~ except` 구문은 프로그램에서 발생할 수 있는 **예외 상황을 처리**하기 위해 사용됩니다. 모든 예외를 조건문으로 처리하는 것은 번거롭고 유지 보수가 어려울 수 있습니다. 예외 처리 구문은 코드의 가독성을 높이고, 예외가 발생했을 때 프로그램이 비정상적으로 종료되지 않고 적절히 대응할 수 있게 해줍니다.
#
#         ### 사용 방법
#
#         - **try 블록**: 예외가 발생할 가능성이 있는 코드를 작성합니다.
#         - **except 블록**: 예외가 발생했을 때 실행할 코드를 작성합니다.
#
#         ```python
#         python코드 복사
#         try:
#             # 예외가 발생할 가능성이 있는 코드
#         except:
#             # 예외가 발생했을 때 실행할 코드
#         ```
#
#         예제:
#
#         ```python
#         python코드 복사
#         try:
#             # 사용자 입력을 정수로 변환
#             number = int(input("숫자를 입력하세요: "))
#             print(f"입력한 숫자는 {number}입니다.")
#         except ValueError:
#             # ValueError가 발생했을 때 실행할 코드
#             print("유효한 숫자가 아닙니다.")
#         ```
#
#         이 코드에서는 사용자가 숫자가 아닌 값을 입력했을 때 `ValueError`가 발생하며, `except` 블록에서 이를 처리합니다. 이렇게 하면 프로그램이 중단되지 않고 오류 메시지를 출력하게 됩니다.
#
#
# 2. finally 구문의 기능과 특징을 설명해주세요
#     - 정답
#
#         ### 기능
#
#         `finally` 구문은 예외 발생 여부와 관계없이 **항상 실행되는 코드**를 작성하는 데 사용됩니다. 이는 리소스 해제, 파일 닫기, 네트워크 연결 종료 등 반드시 실행되어야 하는 코드를 작성할 때 유용합니다.
#
#         ### 특징
#
#         - **항상 실행**: `try` 블록 내에서 예외가 발생하더라도, `finally` 블록의 코드는 반드시 실행됩니다.
#         - **리소스 정리**: 파일, 네트워크 연결 등 리소스를 사용하는 코드에서 리소스를 정리하는 데 유용합니다.
#         - **함수 종료 시 실행**: 함수 내에서 `return` 문이 실행되더라도, `finally` 블록이 먼저 실행된 후 함수가 종료됩니다.
#
#         ```python
#         python코드 복사
#         try:
#             # 파일을 열고 내용을 읽습니다.
#             file = open("example.txt", "r")
#             data = file.read()
#         except FileNotFoundError:
#             # 파일이 존재하지 않을 때의 예외 처리
#             print("파일을 찾을 수 없습니다.")
#         finally:
#             # 예외 발생 여부와 관계없이 파일을 닫습니다.
#             file.close()
#             print("파일이 닫혔습니다.")
#
#         ```
#
#         이 예제에서 `file.close()`는 파일을 열 때 예외가 발생하더라도 반드시 실행됩니다. 이는 파일 리소스를 적절하게 해제하는 데 중요한 역할을 합니다.
#
#         또한, `finally` 블록은 예외 발생 여부와 관계없이 항상 실행된다는 점에서 코드의 안정성을 높여줍니다. 프로그램의 중요한 정리 작업이 누락되지 않도록 보장합니다.
